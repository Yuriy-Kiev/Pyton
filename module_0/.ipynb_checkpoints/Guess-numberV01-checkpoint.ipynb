# %%
import numpy as np


def game_core_v3(number):
    '''Угадываем число методом половинного деления'''
    count = 0
    lower_border = 1
    upper_border = 100
    while True:
        count+=1
        predict = (lower_border+upper_border)//2
        if number == predict: 
            print(count)
            return(count) # выход из цикла, если угадали
        elif number > predict:
            lower_border = predict
        else:
            upper_border = predict
        print(lower_border, upper_border, predict)
        
            
        
def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    count = 0
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1,101, size=(40))
    print(random_array)
    for number in random_array:
        count+= 1
        print('угадываем число', number, 'элемент под номером', count)
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return(score)

score_game(game_core_v3)
# Out:
# [38 13 73 10 76  6 80 65 17  2 77 72  7 26 51 21 19 85 12 29 30 15 51 69
#  88 88 95 97 87 14 10  8 64 62 23 58  2  1 61 82]
# угадываем число 38 элемент под номером 1
# 1 50 50
# 25 50 25
# 37 50 37
# 37 43 43
# 37 40 40
# 6
# угадываем число 13 элемент под номером 2
# 1 50 50
# 1 25 25
# 3
# угадываем число 73 элемент под номером 3
# 50 100 50
# 50 75 75
# 62 75 62
# 68 75 68
# 71 75 71
# 6
# угадываем число 10 элемент под номером 4
# 1 50 50
# 1 25 25
# 1 13 13
# 7 13 7
# 5
# угадываем число 76 элемент под номером 5
# 50 100 50
# 75 100 75
# 75 87 87
# 75 81 81
# 75 78 78
# 6
# угадываем число 6 элемент под номером 6
# 1 50 50
# 1 25 25
# 1 13 13
# 1 7 7
# 4 7 4
# 5 7 5
# 7
# угадываем число 80 элемент под номером 7
# 50 100 50
# 75 100 75
# 75 87 87
# 75 81 81
# 78 81 78
# 79 81 79
# 7
# угадываем число 65 элемент под номером 8
# 50 100 50
# 50 75 75
# 62 75 62
# 62 68 68
# 5
# угадываем число 17 элемент под номером 9
# 1 50 50
# 1 25 25
# 13 25 13
# 13 19 19
# 16 19 16
# 6
# ...
